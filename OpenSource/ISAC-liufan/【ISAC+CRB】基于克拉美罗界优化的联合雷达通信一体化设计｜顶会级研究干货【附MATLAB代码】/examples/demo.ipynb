# %% [markdown]
# # CRB-ISAC Beamforming — Interactive Demo
#
# This notebook demonstrates the CRB-minimizing dual-functional radar-communication (DFRC) beamforming proposed in:
#
# **Cramer-Rao Bound Optimization for Joint Radar-Communication Design**
# *Fan Liu, Ya-Feng Liu, Ang Li, Christos Masouros, Yonina C. Eldar*
# *IEEE TSP 2022 | 🏆 2024 IEEE SPS Best Paper Award*

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '..')

from src.model import SystemParams, CRBModel
from src.solver import SingleUserSolver, MultiUserSDRSolver, BeampatternApproxSolver
from src.metrics import compute_beampattern, MetricsCollector

# %% [markdown]
# ## 1. System Parameters
#
# Use the parameters from Section VII of the paper.

# %%
params = SystemParams(N_t=16, N_p=20, K=4, L=30, P_dBm=30.0, sigma2_dBm=0.0, gamma_dB=15.0)
print(f"N_t={params.N_t}, K={params.K}, L={params.L}, P_r={params.P_dBm}dBm, gamma={params.gamma_dB}dB")

# %% [markdown]
# ## 2. Reproduce Fig. 2 — CRB vs SINR Tradeoff
#
# Run: `python examples/reproduce_fig2.py`

# %% [markdown]
# ## 3. Reproduce Fig. 3 — Beampattern Comparison
#
# Run: `python examples/reproduce_fig3.py`

# %% [markdown]
# ## 4. Your Experiments
#
# Try different parameters and beamforming designs here.
