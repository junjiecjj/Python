# %% [markdown]
# Chapter 11
# # 设置三维图像观察视角
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %%
import matplotlib.pyplot as plt
# 导入Matplotlib的绘图模块

# %%
fig = plt.figure()
# 创建一个新的图形窗口

ax = fig.add_subplot(projection='3d')
# 在图形窗口中添加一个3D坐标轴子图

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# 设置坐标轴的标签

ax.set_proj_type('ortho')
# 设置投影类型为正交投影 (orthographic projection)

ax.view_init(elev=30, azim=30,)
# 设置观察者的仰角为30度，方位角为30度，即改变三维图形的视角

ax.set_box_aspect([1,1,1])
# 设置三个坐标轴的比例一致，使得图形在三个方向上等比例显示

plt.show()
# 显示图形
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4122422/2859507440.py in <module>
#      13 # 设置投影类型为正交投影 (orthographic projection)
#      14
# ---> 15 ax.view_init(elev=30, azim=30,roll = 30)
#      16 # 设置观察者的仰角为30度，方位角为30度，即改变三维图形的视角
#      17
#
# TypeError: view_init() got an unexpected keyword argument 'roll'
